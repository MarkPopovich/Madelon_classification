# %%
# !conda install psycopg2 --yes

# %%
from tqdm import tqdm

# %%
#!conda install psycopg2 --yes
from tqdm import tqdm
import psycopg2 as pg2
from psycopg2.extras import RealDictCursor
import pandas as pd

# def get_data_from_SQL(host_ip, db_name, user_name, query_exe):
#     con = pg2.connect(host=host_ip,
#                       dbname=db_name,
#                       user=user_name)
#     cur = con.cursor(cursor_factory=RealDictCursor)
#     cur.execute(query_exe)
#     results = cur.fetchall()
#     con.close()
    
# con = pg2.connect(host='34.211.227.227',
#                   dbname='postgres',
#                   user='postgres')
# cur = con.cursor(cursor_factory=RealDictCursor)
# cur.execute('SELECT * FROM madelon LIMIT 200;')
# results = cur.fetchall()
# con.close()

# %%
results_df = pd.DataFrame(results)

# %%
results_df.head(1)

# %%
from tqdm import tqdm
import psycopg2 as pg2
from psycopg2.extras import RealDictCursor
import pandas as pd

results_df = pd.DataFrame(results)
conn = pg2.connect(host='34.211.227.227',
                  dbname='postgres',
                  user='postgres')
# cur = con.cursor(cursor_factory=RealDictCursor)
# cur.execute('SELECT * FROM madelon LIMIT 200;')
# results = cur.fetchall()
# con.close()

chunks = pd.read_sql('SELECT * FROM madelon LIMIT 5000', con=conn, chunksize=200)

results = pd.DataFrame()
for chunk in tqdm(chunks):
    results = pd.concat([results, chunk])
    
conn.close()

conn = pg2.connect(host='34.211.227.227',
                  dbname='postgres',
                  user='postgres')
chunks = pd.read_sql('SELECT * FROM madelon LIMIT 5000 OFFSET 5001', con=conn, chunksize=200)

for chunk in tqdm(chunks):
    results = pd.concat([results, chunk])
    
conn.close()
results.shape
# Out:
# 25it [00:04,  6.21it/s]

# %%
results.shape
# Out:
# (5000, 1002)

# %%
results.head()
# Out:
#       _id  feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  \
# 0  199504 -1.094556 -1.289959  1.555434  1.105600 -0.016371 -0.387333
# 1  199505  0.006250 -0.130320  0.890706 -0.071187 -0.111416 -1.911390
# 2  199506  0.317117  0.583337 -1.071065 -1.176961 -0.679162 -0.300227
# 3  199507 -0.785319 -0.552362  1.011398  0.352530  0.669898  0.400467
# 4  199508 -0.045544  0.953394  0.414811  0.013957  0.091641  1.514430
#
#    feat_006  feat_007  feat_008   ...    feat_991  feat_992  feat_993  \
# 0 -1.437222 -2.140276  1.266690   ...    0.286958  1.699065 -2.160862
# 1  0.087192  1.142022 -2.152782   ...   -0.759345  0.433783  1.579361
# 2  0.007687  0.803629 -0.292915   ...    0.339596 -0.321123  0.371883
# 3 -0.762796 -0.390103 -1.156768   ...   -0.046988  0.761697 -0.298429
# 4 -0.487423 -1.882189 -0.177943   ...    0.888259 -0.755479 -0.095518
#
#    feat_994  feat_995  feat_996  feat_997  feat_998  feat_999  target
# ...

# %%
conn = pg2.connect(host='34.211.227.227',
                  dbname='postgres',
                  user='postgres')
chunks = pd.read_sql('SELECT * FROM madelon LIMIT 5000 OFFSET 5001', con=conn, chunksize=200)

for chunk in tqdm(chunks):
    results = pd.concat([results, chunk])
    
conn.close()
results.shape
# Out:
# 25it [00:05,  4.90it/s]
# (10000, 1002)

# %%
results
# Out:
#         _id  feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  \
# 0    199504 -1.094556 -1.289959  1.555434  1.105600 -0.016371 -0.387333
# 1    199505  0.006250 -0.130320  0.890706 -0.071187 -0.111416 -1.911390
# 2    199506  0.317117  0.583337 -1.071065 -1.176961 -0.679162 -0.300227
# 3    199507 -0.785319 -0.552362  1.011398  0.352530  0.669898  0.400467
# 4    199508 -0.045544  0.953394  0.414811  0.013957  0.091641  1.514430
# 5    199509  0.344513 -1.158802 -0.381662  0.760770 -0.699443  0.913892
# 6    199510  0.160218 -0.733478 -1.204747  0.449186 -0.007135 -1.150787
# 7    199511  0.502287  1.848897 -0.735488 -1.276410 -0.382397 -1.442939
# 8    199512 -1.885001 -1.965690  0.314713 -0.445505 -0.306333 -0.158700
# 9    199513 -0.161291  0.234069 -1.333018  1.316003 -0.098494  0.931752
# 10   199514  1.386148  2.214298  1.527739 -0.232430  0.635267 -0.981360
# 11   199515 -0.820518  0.188509  2.559017  0.167249 -1.076211  0.175590
# ...

# %%
results[9999:10000]
# Out:
#        _id  feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  \
# 199  14496  0.311384 -0.347482 -0.727624  0.299435  1.653224 -0.620932
#
#      feat_006  feat_007  feat_008   ...    feat_991  feat_992  feat_993  \
# 199 -0.154927 -0.185812  0.626058   ...   -0.260008 -0.822217  0.189228
#
#      feat_994  feat_995  feat_996  feat_997  feat_998  feat_999  target
# 199  0.205118  1.411836 -0.216953 -0.711156 -0.644604  1.114137       0
#
# [1 rows x 1002 columns]
